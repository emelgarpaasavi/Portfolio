# %% [markdown]
# Dataset source: https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata
#
# Objectives:
# 1. The cleaned data will be used for analysis of airbnb houses with "no-smoking" policy in New York.
# 2. Get only columns that are relevant for data analysis. Remove columns: id, host name, lat, long, country, country code and license (since the id for each reviewer, host name and license are irrelevant for the analysis, and it only focuses on the local scene (neighbourhood area))
# 3. Remove duplicates (if there are any)
# 4. Check neighbourhood group, update inconsistencies in spelling (Brooklyn and Manhattan)
# 5. Fill null values with:
#    - "Unknown" (for categorical/object type columns: NAME, host_identity_verified, instant_bookable, cancellation_policy,  house_rules)
# 6. Under house_rules, only get data that has no smoking policy
# 7. Do not include rows with no price AND service fee (if there are any)
# 8. Add new columns:
#    "> 0 min nights", "<= 2022 last review"
#    - Values: Yes/No
#    - "> 0 min nights" column description:
#        - Yes for data in "minimum nights" column that are > 0,
#        - No if < 0
#    - "<= 2022 last review" column description:
#        - Yes for data in "last review" column that are <= 2022,
#        - No if > 2022
#    - Reason for adding: There are outlier values for the following numeric type columns. The newly added columns may be used in analysis by dividing them from other data.

# %%
import pandas as pd

# %%
# Read Airbnb csv file
df = pd.read_csv("Airbnb_Open_Data.csv")
# Check first 5 rows of Airbnb_Open_Data
df.head()
# Out:
# C:\Users\Emelgar Rey Jahsua\AppData\Local\Temp\ipykernel_4108\3731740676.py:2: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Airbnb_Open_Data.csv")
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0    7/5/2019               4.64                4.0
# 4               9.0  11/19/2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %%
# Get only columns that are relevant for data analysis. 
# Remove columns: id, host name, lat, long, country, country code and license
unwanted_columns = ['id', 'host name', 'lat', 'long', 'country', 'country code', 'license']
df.drop(unwanted_columns, axis=1, inplace=True)
# Display updated dataset
display(df)
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102053               Cozy bright room near Prospect Park  77326652202
# 102054         Private Bedroom with Amazing Rooftop View  45936254757
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people  23801060917
# 102056        Room & private bathroom in historic Harlem  15593031571
# 102057                                   Rosalee Stewart  93578954226
#
#        host_identity_verified neighbourhood group       neighbourhood  \
# 0                 unconfirmed            Brooklyn          Kensington
# 1                    verified           Manhattan             Midtown
# 2                         NaN           Manhattan              Harlem
# 3                 unconfirmed            Brooklyn        Clinton Hill
# 4                    verified           Manhattan         East Harlem
# ...                       ...                 ...                 ...
# 102053            unconfirmed            Brooklyn            Flatbush
# 102054               verified            Brooklyn            Bushwick
# 102055               verified            Brooklyn  Bedford-Stuyvesant
# 102056            unconfirmed           Manhattan              Harlem
# 102057               verified           Manhattan              Harlem
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 2                  True            flexible     Private room
# 3                  True            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102053             True            moderate     Private room
# 102054            False            flexible     Private room
# 102055             True            moderate  Entire home/apt
# 102056             True              strict     Private room
# 102057            False            flexible  Entire home/apt
#
#         Construction year    price service fee  minimum nights  \
# 0                  2020.0    $966        $193             10.0
# 1                  2007.0    $142         $28             30.0
# 2                  2005.0    $620        $124              3.0
# 3                  2005.0    $368         $74             30.0
# 4                  2009.0    $204         $41             10.0
# ...                   ...      ...         ...             ...
# 102053                NaN    $696          NaN             7.0
# 102054                NaN    $909          NaN             1.0
# 102055                NaN    $387          NaN             2.0
# 102056                NaN    $848          NaN             2.0
# 102057             2011.0  $1,128          NaN             4.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102053               12.0   3/27/2019               0.44                 5.0
# 102054               19.0   8/31/2017               0.72                 3.0
# 102055               50.0   6/26/2019               3.12                 4.0
# 102056                0.0         NaN                NaN                 1.0
# 102057               22.0   6/15/2019               0.85                 4.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102053                             1.0               0.0
# 102054                             2.0               0.0
# 102055                             2.0             235.0
# 102056                             1.0               0.0
# 102057                             1.0             238.0
#
#                                               house_rules
# 0       Clean up and treat the home the way you'd like...
# 1       Pet friendly but please confirm with me if the...
# 2       I encourage you to use my kitchen, cooking and...
# 3                                                     NaN
# 4       Please no smoking in the house, porch or on th...
# ...                                                   ...
# 102053  Shoes off Clean After yourself Turn Lights and...
# 102054                                             #NAME?
# 102055  * Check out: 10am * We made an effort to keep ...
# 102056  Each of us is working and/or going to school a...
# 102057  Please remember that this is a residential bui...
#
# [102058 rows x 19 columns]

# %%
# Remove duplicates (if there are any)
# Check if there are any duplicates by grouping the data by column and getting each size
duplicated_rows = df.groupby(df.columns.tolist(), as_index=False).size()
display(duplicated_rows[duplicated_rows['size'] > 1])
# Out:
# Empty DataFrame
# Columns: [NAME, host id, host_identity_verified, neighbourhood group, neighbourhood, instant_bookable, cancellation_policy, room type, Construction year, price, service fee, minimum nights, number of reviews, last review, reviews per month, review rate number, calculated host listings count, availability 365, house_rules, size]
# Index: []

# %%
# There are no duplicates to remove
df.drop_duplicates(inplace=True)
print(df.shape[0])
# Out:
# 102058

# %%
# Check neighbourhood group, update inconsistencies in spelling (Brooklyn and Manhattan)
# There are cases that Brooklyn is brookln and Manhattan is manhatan
print(df['neighbourhood group'].value_counts())
# Out:
# Manhattan        43558
# Brooklyn         41631
# Queens           13197
# Bronx             2694
# Staten Island      949
# Name: neighbourhood group, dtype: int64

# %%
# Set to correct spelling
df[df['neighbourhood group'] == 'brookln'] = "Brooklyn"
df[df['neighbourhood group'] == 'manhatan'] = "Manhattan"
print(df['neighbourhood group'].value_counts())
# Out:
# Manhattan        43558
# Brooklyn         41631
# Queens           13197
# Bronx             2694
# Staten Island      949
# Name: neighbourhood group, dtype: int64

# %%
# Fill null values with:
# "Unknown" (for categorical/object type columns: NAME, host_identity_verified, 
#            instant_bookable, cancellation_policy, house_rules)
categorical_columns = {'NAME': 'Unknown', 
                       'host_identity_verified': 'Unknown', 
                       'instant_bookable': 'Unknown', 
                       'cancellation_policy': 'Unknown', 
                       'house_rules': 'Unknown'}
df = df.fillna(categorical_columns)

# %%
# Check dataframe to check if there are no null values
print(df[['NAME', 'host_identity_verified', 'instant_bookable', 'cancellation_policy', 'house_rules']].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102058 entries, 0 to 102057
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   NAME                    102058 non-null  object
#  1   host_identity_verified  102058 non-null  object
#  2   instant_bookable        102058 non-null  object
#  3   cancellation_policy     102058 non-null  object
#  4   house_rules             102058 non-null  object
# dtypes: object(5)
# memory usage: 4.7+ MB
# None

# %%
# Under house_rules column, only get data that has no smoking policy
# Check values that contains: no, non, smoke, smoking, '-' in between words
smoke_kw_airbnb = df[df['house_rules'].str.contains('smok', case=False)]
no_smok_kw_airbnb = smoke_kw_airbnb[smoke_kw_airbnb['house_rules'].str.contains('no smok', case=False)]
no_dash_smok_kw_airbnb = smoke_kw_airbnb[smoke_kw_airbnb['house_rules'].str.contains('no-smok', case=False)]
non_smok_kw_airbnb = smoke_kw_airbnb[smoke_kw_airbnb['house_rules'].str.contains('non smok', case=False)]
non_dash_smok_kw_airbnb = smoke_kw_airbnb[smoke_kw_airbnb['house_rules'].str.contains('non-smok', case=False)]

# Merge dataframes and remove duplicates
merged_kw = pd.concat([no_smok_kw_airbnb, no_dash_smok_kw_airbnb, non_smok_kw_airbnb, non_dash_smok_kw_airbnb])
no_smoking_policy_airbnbs = merged_kw.drop_duplicates()

# %%
# Show no_smoking_policy_airbnbs table
display(no_smoking_policy_airbnbs)
# Out:
#                                                      NAME      host id  \
# 0                      Clean & quiet apt home by the park  80014485718
# 2                     THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 4        Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5               Large Cozy 1 BR Apartment In Midtown East  45498551794
# 6                                         BlissArtsSpace!  61300605564
# ...                                                   ...          ...
# 101759         First Floor Studio on the Upper East Side!  33411205113
# 101787              Spacious Bed and Bathroom in Brooklyn  82554454538
# 101794  Private Sunny Room in Williamsburg, Brooklyn - NY  12776982396
# 101855                        Brooklyn Cave in the Neighb  93010217247
# 101889         Luxe Large Suite w/Views bathroom en suite  31381154069
#
#        host_identity_verified neighbourhood group       neighbourhood  \
# 0                 unconfirmed            Brooklyn          Kensington
# 2                     Unknown           Manhattan              Harlem
# 4                    verified           Manhattan         East Harlem
# 5                    verified           Manhattan         Murray Hill
# 6                     Unknown            Brooklyn  Bedford-Stuyvesant
# ...                       ...                 ...                 ...
# 101759            unconfirmed           Manhattan     Upper East Side
# 101787               verified            Brooklyn      Sheepshead Bay
# 101794               verified            Brooklyn        Williamsburg
# 101855               verified            Brooklyn            Canarsie
# 101889            unconfirmed            Brooklyn   Downtown Brooklyn
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 2                  True            flexible     Private room
# 4                 False            moderate  Entire home/apt
# 5                  True            flexible  Entire home/apt
# 6                 False            moderate     Private room
# ...                 ...                 ...              ...
# 101759             True            moderate  Entire home/apt
# 101787             True            flexible     Private room
# 101794             True            moderate     Private room
# 101855             True              strict  Entire home/apt
# 101889             True            moderate     Private room
#
#        Construction year    price service fee minimum nights  \
# 0                 2020.0    $966        $193            10.0
# 2                 2005.0    $620        $124             3.0
# 4                 2009.0    $204         $41            10.0
# 5                 2013.0    $577        $115             3.0
# 6                 2015.0     $71         $14            45.0
# ...                  ...      ...         ...            ...
# 101759            2006.0    $809        $162             3.0
# 101787            2017.0    $406         $81             1.0
# 101794            2005.0    $736        $147             2.0
# 101855            2011.0  $1,033        $207             2.0
# 101889            2015.0    $872        $174             3.0
#
#        number of reviews last review reviews per month review rate number  \
# 0                    9.0  10/19/2021              0.21                4.0
# 2                    0.0         NaN               NaN                5.0
# 4                    9.0  11/19/2018               0.1                3.0
# 5                   74.0   6/22/2019              0.59                3.0
# 6                   49.0   10/5/2017               0.4                5.0
# ...                  ...         ...               ...                ...
# 101759              30.0   6/28/2019              1.08                1.0
# 101787               1.0   2/25/2017              0.03                2.0
# 101794               4.0    1/2/2019              0.14                5.0
# 101855              68.0    7/1/2019               3.5                2.0
# 101889              28.0    6/9/2019               1.0                4.0
#
#        calculated host listings count availability 365  \
# 0                                 6.0            286.0
# 2                                 1.0            352.0
# 4                                 1.0            289.0
# 5                                 1.0            374.0
# 6                                 1.0            224.0
# ...                               ...              ...
# 101759                            1.0              4.0
# 101787                            1.0              0.0
# 101794                            2.0              0.0
# 101855                            1.0            240.0
# 101889                            2.0             11.0
#
#                                               house_rules
# 0       Clean up and treat the home the way you'd like...
# 2       I encourage you to use my kitchen, cooking and...
# 4       Please no smoking in the house, porch or on th...
# 5                       No smoking, please, and no drugs.
# 6       Please no shoes in the house so bring slippers...
# ...                                                   ...
# 101759  We live on the premises - two women,  two dogs...
# 101787  THIS IS A NON-SMOKING RESIDENCE. NO Children u...
# 101794  This is a non-smoking, pet friendly house. Ple...
# 101855  THIS IS A NON-SMOKING RESIDENCE. NO Children u...
# 101889  Our home is well cared for and loved. We would...
#
# [26347 rows x 19 columns]

# %%
# Do not include rows with no price AND service fee (if there are any)
# Count rows that have no price and service fees in no_smoking_policy_airbnbs
no_price_and_fees = no_smoking_policy_airbnbs[no_smoking_policy_airbnbs['price'].isnull() & 
                                                    no_smoking_policy_airbnbs['service fee'].isnull()]
print(f"There are {no_price_and_fees.shape[0]} Airbnb hosts with no smoking policy that has both no price and service fees.")
# Out:
# There are 7 Airbnb hosts with no smoking policy that has both no price and service fees.

# %%
# Remove no_price_and_fees rows
cleaned_no_smoking_airbnbs = no_smoking_policy_airbnbs.drop(no_price_and_fees.index)
print(cleaned_no_smoking_airbnbs.shape[0])
# Out:
# 26340

# %%
# Reset Index
cleaned_no_smoking_airbnbs.reset_index(drop=True, inplace=True)

# %%
# Add new columns: "> 0 min nights", "<= 2022 last review"
# First, count rows that have < 0 min nights (outlier values) in the 'minimum nights' column
# The data used is not null
min_nights_notnull = cleaned_no_smoking_airbnbs[cleaned_no_smoking_airbnbs['minimum nights'].notnull()]
min_nights_outliers = min_nights_notnull[min_nights_notnull['minimum nights'] < 0]['minimum nights']
print(f" There are {min_nights_outliers.count()} rows with < 0 min nights")
# Out:
#  There are 4 rows with < 0 min nights

# %%
# Add column: "> 0 min nights"
# Yes for data in "minimum nights" column that are > 0, No if < 0
cleaned_no_smoking_airbnbs['> 0 min nights'] = min_nights_notnull['minimum nights'].apply(lambda x: 'Yes' if x > 0 else 'No')

# %%
# Check outliers if '> 0 min nights' column is 'No' 
display(cleaned_no_smoking_airbnbs[cleaned_no_smoking_airbnbs['minimum nights'] < 0])
# Out:
#                                                     NAME      host id  \
# 81                   BROOKLYN VICTORIAN STYLE SUITE.....  83631499592
# 14293  2bd BOUTIQUE  Apartament in the heart of MANHA...   2679070022
# 14300                   Newly Renovated Garden Apartment  98469733112
# 21676                            Cozy Brooklyn Apartment  63988893317
#
#       host_identity_verified neighbourhood group       neighbourhood  \
# 81               unconfirmed            Brooklyn         Fort Greene
# 14293            unconfirmed           Manhattan      Hell's Kitchen
# 14300               verified            Brooklyn  Bedford-Stuyvesant
# 21676               verified            Brooklyn             Gowanus
#
#       instant_bookable cancellation_policy        room type Construction year  \
# 81               False            flexible     Private room            2008.0
# 14293             True            flexible  Entire home/apt            2009.0
# 14300             True            moderate  Entire home/apt            2022.0
# 21676             True            moderate      Shared room            2014.0
#
#          price service fee minimum nights number of reviews last review  \
# 81     $1,155        $231           -10.0             213.0   6/24/2019
# 14293    $711        $142          -365.0              13.0    7/7/2019
# 14300     $85         $17          -200.0               3.0   4/23/2019
# 21676  $1,177        $235           -10.0               9.0    5/8/2017
#
#       reviews per month review rate number calculated host listings count  \
# 81                  2.0                5.0                            2.0
# 14293              5.91                4.0                            4.0
# 14300              1.06                2.0                            1.0
# 21676              0.31                2.0                            1.0
#
#       availability 365                                        house_rules  \
# 81                19.0  There is no smoking on the property. No outsid...
# 14293              0.0  Please pick up/drop packet with front desk con...
# 14300            157.0  No smoking or pets allowed and we request that...
# 21676              0.0  No smoking, No pets. No shoes in the house. Vi...
#
#       > 0 min nights
# 81                No
# 14293             No
# 14300             No
# 21676             No

# %%
# Check last reviews whose year is > 2022 (outlier values) in the 'last review' column
# The data used is not null
last_review_not_null = cleaned_no_smoking_airbnbs[cleaned_no_smoking_airbnbs['last review'].notnull()]

# Split the date by / and get the 3rd index ([2])
last_review_year = last_review_not_null['last review'].str.split('/').str[2].astype(int)
# Display rows whose year is > 2022
display(last_review_not_null[last_review_year > 2022])
# Out:
#                                     NAME      host id host_identity_verified  \
# 61   Garden studio in the Upper East Sid  77172555024            unconfirmed
# 107          Beautiful Landmarked Duplex  87944779917                Unknown
# 132                              Unknown  70084472212               verified
#
#     neighbourhood group    neighbourhood instant_bookable cancellation_policy  \
# 61            Manhattan  Upper East Side            False              strict
# 107            Brooklyn       Greenpoint             True            moderate
# 132            Brooklyn       Greenpoint             True            flexible
#
#            room type Construction year  price service fee minimum nights  \
# 61   Entire home/apt            2007.0  $571        $114             5.0
# 107  Entire home/apt            2008.0  $842        $168             3.0
# 132     Private room            2018.0  $920        $184             2.0
#
#     number of reviews last review reviews per month review rate number  \
# 61               21.0   8/15/2024              0.19                4.0
# 107             124.0   6/16/2058              1.22                4.0
# 132               1.0   3/28/2026              0.01                3.0
#
#     calculated host listings count availability 365  \
# 61                             NaN            395.0
# 107                            3.0            230.0
# 132                            1.0             73.0
#
#                                            house_rules > 0 min nights
# 61   Dear Guests, Welcome to 62 Cornwall St! I hope...            Yes
# 107  No rules per say. I just ask that you respect ...            Yes
# 132  Check-In is 3pm.  Check-Out is 12 Noon.  In or...            Yes

# %%
# Add column: "<= 2022 last review"
# Yes for data in "last review" column that are <= 2022, No if > 2022
cleaned_no_smoking_airbnbs['<= 2022 last review'] = last_review_year.apply(lambda x: 'Yes' if x <= 2022 else 'No')

# %%
# Check outliers if '<= 2022 last review' column is 'No' 
display(cleaned_no_smoking_airbnbs[cleaned_no_smoking_airbnbs['<= 2022 last review'] == 'No'])
# Out:
#                                     NAME      host id host_identity_verified  \
# 61   Garden studio in the Upper East Sid  77172555024            unconfirmed
# 107          Beautiful Landmarked Duplex  87944779917                Unknown
# 132                              Unknown  70084472212               verified
#
#     neighbourhood group    neighbourhood instant_bookable cancellation_policy  \
# 61            Manhattan  Upper East Side            False              strict
# 107            Brooklyn       Greenpoint             True            moderate
# 132            Brooklyn       Greenpoint             True            flexible
#
#            room type Construction year  price  ... minimum nights  \
# 61   Entire home/apt            2007.0  $571   ...            5.0
# 107  Entire home/apt            2008.0  $842   ...            3.0
# 132     Private room            2018.0  $920   ...            2.0
#
#     number of reviews last review reviews per month review rate number  \
# 61               21.0   8/15/2024              0.19                4.0
# 107             124.0   6/16/2058              1.22                4.0
# 132               1.0   3/28/2026              0.01                3.0
#
#     calculated host listings count availability 365  \
# 61                             NaN            395.0
# 107                            3.0            230.0
# 132                            1.0             73.0
#
#                                            house_rules > 0 min nights  \
# 61   Dear Guests, Welcome to 62 Cornwall St! I hope...            Yes
# 107  No rules per say. I just ask that you respect ...            Yes
# 132  Check-In is 3pm.  Check-Out is 12 Noon.  In or...            Yes
#
#     <= 2022 last review
# 61                   No
# 107                  No
# 132                  No
#
# [3 rows x 21 columns]

# %%
# Export cleaned_no_smoking_airbnbs as csv
cleaned_no_smoking_airbnbs.to_csv('cleaned_no_smoking_airbnbs.csv', index=False)
